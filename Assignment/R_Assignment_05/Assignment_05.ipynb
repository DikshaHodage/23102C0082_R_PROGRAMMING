# %%
x = c(11, NA, 13, NA)
is.na(x)
mean(x)
mean(x, na.rm = TRUE)

# %% [markdown]
# NA vs NULL

# %%
x
sum(is.na(x))
complete.cases(x)
y = na.omit(x)
y

# %% [markdown]
# Control Structures (If/Else)

# %%
x = 6
if (x > 5) x * 3
x = 4
if (x > 5) x * 3

# %% [markdown]
# With using {}

# %%
x = 6
if (x > 5) {x * 3}
x = 4
if (x > 5) {x * 3}
if (x > 3) {
  print("x is greater than 3")
}

# %%
if (x == 4) {
  x = x - 1
} else {
  x = 2 + x
}
x

# %%
x = 25
ifelse(x == 25, x / 5, x + 2)
switch(
  "color",
  "color" = "blue",
  "gender" = "male"
)

# %%
x = c(10, 15, 20, 25, 22)
which(x == 7)
which(x == 10)
which.min(x)
which.max(x)

# %%
x = matrix(nrow = 3, ncol = 3, data = 1:9)
x
which.min(x)
which.max(x)
