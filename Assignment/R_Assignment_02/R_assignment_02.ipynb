# %%
c(2,3,5,7) + c(-2,-3,-5,8)
# Out:
# [1]  0  0  0 15

# %%
c(2,3,5,7) + c(8,9)
# Out:
# [1] 10 12 13 16

# %%
c(2,3,5,7) + c(8,9,10)
# Out:
# Warning message in c(2, 3, 5, 7) + c(8, 9, 10):
# “longer object length is not a multiple of shorter object length”
# [1] 10 12 15 15

# %% [markdown]
# **Subtraction with data vectors**

# %%
c(2,3,5,7) - c(-2,-3,-5,8)
c(12,13,15,17) - c(8,9)
c(12,13,15,17) - c(8,9,10)
# Out:
# [1]  4  6 10 -1
# [1] 4 4 7 8
# Warning message in c(12, 13, 15, 17) - c(8, 9, 10):
# “longer object length is not a multiple of shorter object length”
# [1] 4 4 5 9

# %% [markdown]
# **Multiplication and Division with data vectors & constants**

# %%
c(2,3,5,7) * c(8,9)
c(2,3,5,7) * c(8,9,10)
c(24,20,8,16) / c(3,4,2,8)
c(24,20,8,16) / c(4,2)
# Out:
# [1] 16 27 40 63
# Warning message in c(2, 3, 5, 7) * c(8, 9, 10):
# “longer object length is not a multiple of shorter object length”
# [1] 16 27 50 56
# [1] 8 5 4 2
# [1]  6 10  2  8

# %% [markdown]
# **Assignment Operators & Storage Modes**

# %%
x = 20
x <- 20
x = "apple"
is.numeric(x)
is.character(x)
y = as.character(x)
is.numeric(y)
mode(x)
storage.mode(x)
# Out:
# [1] FALSE
# [1] TRUE
# [1] FALSE
# [1] "character"
# [1] "character"

# %% [markdown]
# **Inf and Finite Checks & Scalar Math**

# %%
5 + Inf
is.finite(5 + Inf)
is.infinite(5 + Inf)
c(2,3,5,7) + 10
c(12,13,15,17) - 10
c(12,13,15,17) / 10
# Out:
# [1] Inf
# [1] FALSE
# [1] TRUE
# [1] 12 13 15 17
# [1] 2 3 5 7
# [1] 1.2 1.3 1.5 1.7
