# %% [markdown]
# **R as a Calculator**

# %% [markdown]
# Power operator

# %%
2^3
# Out:
# [1] 8

# %%
2**3
# Out:
# [1] 8

# %%
2^0.5
# Out:
# [1] 1.414214

# %%
2^-0.5
# Out:
# [1] 0.7071068

# %% [markdown]
# Vector operations

# %%
c(2,3,5,7)^2
# Out:
# [1]  4  9 25 49

# %%
c(2,3,5,7)^c(2,3)
# Out:
# [1]   4  27  25 343

# %% [markdown]
# Integer division with scalar

# %%
2 %/% 2
# Out:
# [1] 1

# %%
3 %/% 2
# Out:
# [1] 1

# %%
c(1, 2, 3, 4) %/% 3
# Out:
# [1] 0 0 1 1

# %% [markdown]
# Integer division with vectors

# %%
c(2,3,5,7)%/%c(2,3)
# Out:
# [1] 1 1 2 2

# %% [markdown]
# Modulo division

# %%
2 %% 2
# Out:
# [1] 0

# %% [markdown]
# Vector modulo divided by scalar

# %%
c(1, 2, 3, 4) %% 3
# Out:
# [1] 1 2 0 1

# %% [markdown]
# Vector modulo vector

# %%
c(2,3,5,7)%%c(2,3)
# Out:
# [1] 0 0 1 1

# %% [markdown]
# Max and Min function

# %%
max(1 , 2, 3)
# Out:
# [1] 3

# %%
min(1 , 2, 3)
# Out:
# [1] 1

# %%
mean(c(2, 3, 4))
# Out:
# [1] 3

# %% [markdown]
# Arithmetic Functions

# %%
abs(-4)
abs(4)
# Out:
# [1] 4
# [1] 4

# %%
sqrt(4)
sqrt(c(2, 4, 5, 6))
# Out:
# [1] 2
# [1] 1.414214 2.000000 2.236068 2.449490

# %%
sum(c(2, 3,4,5))
# Out:
# [1] 14

# %%
prod(c(2, 3,4,5))
# Out:
# [1] 120

# %%
round(1.234545)
round(1.83)
# Out:
# [1] 1
# [1] 2

# %%
log(10)
log(exp(2))
log10(100)
# Out:
# [1] 2.302585
# [1] 2
# [1] 2

# %% [markdown]
# Assignment

# %%
x1 = c(2,3,4,5)
x1
# Out:
# [1] 2 3 4 5

# %% [markdown]
# Matrix

# %%
x = matrix(nrow = 2, ncol = 2, data = c(1, 2 , 3,4))
x
x[1, 2]
# Out:
#      [,1] [,2]
# [1,] 1    3
# [2,] 2    4
# [1] 3

# %%
x = matrix(nrow = 2, ncol = 2, data = c(1, 2.43 , 3,FALSE), byrow = TRUE)
x
# Out:
#      [,1] [,2]
# [1,] 1    2.43
# [2,] 3    0.00

# %% [markdown]
# Methods of matrices

# %%
dim(x)
nrow(x)
ncol(x)
# Out:
# [1] 2 2
# [1] 2
# [1] 2

# %%
mode(x)
# Out:
# [1] "numeric"
